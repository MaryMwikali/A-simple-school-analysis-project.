# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
census_population=pd.read_csv('census_population.csv')
census_population
# Out:
#        State Code  District Code  Sub District Code      Category  \
# 0               0              0                  0         INDIA
# 1               0              0                  0         INDIA
# 2               0              0                  0         INDIA
# 3               1              0                  0         STATE
# 4               1              0                  0         STATE
# ...           ...            ...                ...           ...
# 19987          35            640               5923  SUB-DISTRICT
# 19988          35            640               5923  SUB-DISTRICT
# 19989          35            640               5924  SUB-DISTRICT
# 19990          35            640               5924  SUB-DISTRICT
# 19991          35            640               5924  SUB-DISTRICT
#
#                   Name Residence  Inhabited Villages  Uninhabited Villages  \
# 0                INDIA     Total              597608                 43324
# ...

# %% [markdown]
# # DATA PREPROCESSING

# %%
census_clean=census_population.dropna()
census_clean
# Out:
#        State Code  District Code  Sub District Code      Category  \
# 0               0              0                  0         INDIA
# 1               0              0                  0         INDIA
# 2               0              0                  0         INDIA
# 3               1              0                  0         STATE
# 4               1              0                  0         STATE
# ...           ...            ...                ...           ...
# 19987          35            640               5923  SUB-DISTRICT
# 19988          35            640               5923  SUB-DISTRICT
# 19989          35            640               5924  SUB-DISTRICT
# 19990          35            640               5924  SUB-DISTRICT
# 19991          35            640               5924  SUB-DISTRICT
#
#                   Name Residence  Inhabited Villages  Uninhabited Villages  \
# 0                INDIA     Total              597608                 43324
# ...

# %%
cleaned_census=census_clean.drop_duplicates()
cleaned_census
# Out:
#        State Code  District Code  Sub District Code      Category  \
# 0               0              0                  0         INDIA
# 1               0              0                  0         INDIA
# 2               0              0                  0         INDIA
# 3               1              0                  0         STATE
# 4               1              0                  0         STATE
# ...           ...            ...                ...           ...
# 19987          35            640               5923  SUB-DISTRICT
# 19988          35            640               5923  SUB-DISTRICT
# 19989          35            640               5924  SUB-DISTRICT
# 19990          35            640               5924  SUB-DISTRICT
# 19991          35            640               5924  SUB-DISTRICT
#
#                   Name Residence  Inhabited Villages  Uninhabited Villages  \
# 0                INDIA     Total              597608                 43324
# ...

# %%
cleaned_census.columns
# Out:
# Index(['State Code', 'District Code', 'Sub District Code', 'Category', 'Name',
#        'Residence', 'Inhabited Villages', 'Uninhabited Villages', 'Towns',
#        'Households', 'Population (Person)', 'Population (Male)',
#        'Population (Female)', 'Area', 'Population Density'],
#       dtype='object')

# %%
cleaned_census.dtypes
# Out:
# State Code                int64
# District Code             int64
# Sub District Code         int64
# Category                 object
# Name                     object
# Residence                object
# Inhabited Villages        int64
# Uninhabited Villages      int64
# Towns                     int64
# Households                int64
# Population (Person)       int64
# Population (Male)         int64
# Population (Female)       int64
# Area                    float64
# Population Density      float64
# dtype: object

# %%
cleaned_census['Category'].count()
# Out:
# 19875

# %%
Category=cleaned_census.pivot_table(cleaned_census,index=['Category'],aggfunc='size')
Category
# Out:
# Category
# DISTRICT         1883
# INDIA               3
# STATE             103
# SUB-DISTRICT    17886
# dtype: int64

# %%
Inhabited_villages=cleaned_census.pivot_table(cleaned_census, index=['Inhabited Villages'],aggfunc='size')
Inhabited_villages
# Out:
# Inhabited Villages
# 0         6832
# 1           28
# 2           41
# 3           28
# 4           36
#           ...
# 43264        2
# 47675        2
# 51929        2
# 97814        2
# 597608       2
# Length: 894, dtype: int64

# %%
Uninhabited_villages=cleaned_census.pivot_table(cleaned_census, index=['Uninhabited Villages'], aggfunc='size')
Uninhabited_villages
# Out:
# Uninhabited Villages
# 0        10670
# 1         1672
# 2         1003
# 3          781
# 4          527
#          ...
# 2974         2
# 3636         2
# 5801         2
# 8960         2
# 43324        2
# Length: 224, dtype: int64

# %%
#positive correlation
Corr=cleaned_census['Inhabited Villages'].corr(cleaned_census['Uninhabited Villages'])
Corr
# Out:
# 0.9933959280861335

# %%
cleaned_census.describe()
# Out:
#          State Code  District Code  Sub District Code  Inhabited Villages  \
# count  19875.000000   19875.000000       19875.000000        19875.000000
# mean      19.274818     362.930063        3104.912201          239.948679
# std        8.684109     171.528692        6790.535036         6211.251229
# min        0.000000       0.000000           0.000000            0.000000
# 25%       10.000000     229.000000         994.000000            0.000000
# 50%       21.000000     376.000000        2641.000000           29.000000
# 75%       28.000000     533.000000        4296.500000          118.000000
# max       35.000000     640.000000       99999.000000       597608.000000
#
#        Uninhabited Villages         Towns    Households  Population (Person)  \
# count          19875.000000  19875.000000  1.987500e+04         1.987500e+04
# mean              17.401107      3.188277  1.003916e+05         4.872025e+05
# ...

# %%
cleaned_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19875 entries, 0 to 19991
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State Code            19875 non-null  int64
#  1   District Code         19875 non-null  int64
#  2   Sub District Code     19875 non-null  int64
#  3   Category              19875 non-null  object
#  4   Name                  19875 non-null  object
#  5   Residence             19875 non-null  object
#  6   Inhabited Villages    19875 non-null  int64
#  7   Uninhabited Villages  19875 non-null  int64
#  8   Towns                 19875 non-null  int64
#  9   Households            19875 non-null  int64
#  10  Population (Person)   19875 non-null  int64
#  11  Population (Male)     19875 non-null  int64
#  12  Population (Female)   19875 non-null  int64
#  13  Area                  19875 non-null  float64
#  14  Population Density    19875 non-null  float64
# ...

# %%
#they have a positive correlation since its correlation coefficient is 0.99
#as the male increases, the female also increases
corr=cleaned_census['Population (Male)'].corr(cleaned_census['Population (Female)'])
corr
# Out:
# 0.9999397495743911

# %%
cleaned_census.head()
# Out:
#    State Code  District Code  Sub District Code Category             Name  \
# 0           0              0                  0    INDIA            INDIA
# 1           0              0                  0    INDIA            INDIA
# 2           0              0                  0    INDIA            INDIA
# 3           1              0                  0    STATE  JAMMU & KASHMIR
# 4           1              0                  0    STATE  JAMMU & KASHMIR
#
#   Residence  Inhabited Villages  Uninhabited Villages  Towns  Households  \
# 0     Total              597608                 43324   7933   249501663
# 1     Rural              597608                 43324      0   168612897
# 2     Urban                   0                     0   7933    80888766
# 3     Total                6337                   216    122     2119718
# 4     Rural                6337                   216      0     1553433
#
#    Population (Person)  Population (Male)  Population (Female)        Area  \
# ...

# %%
cleaned_census[cleaned_census["Category"]=="STATE"]
# Out:
#        State Code  District Code  Sub District Code Category  \
# 3               1              0                  0    STATE
# 4               1              0                  0    STATE
# 5               1              0                  0    STATE
# 318             2              0                  0    STATE
# 319             2              0                  0    STATE
# ...           ...            ...                ...      ...
# 19915          34              0                  0    STATE
# 19916          34              0                  0    STATE
# 19953          35              0                  0    STATE
# 19954          35              0                  0    STATE
# 19955          35              0                  0    STATE
#
#                             Name Residence  Inhabited Villages  \
# 3                JAMMU & KASHMIR     Total                6337
# 4                JAMMU & KASHMIR     Rural                6337
# ...

# %%
cleaned_census[cleaned_census['Residence']=='Rural']
# Out:
#        State Code  District Code  Sub District Code      Category  \
# 1               0              0                  0         INDIA
# 4               1              0                  0         STATE
# 7               1              1                  0      DISTRICT
# 10              1              1                  1  SUB-DISTRICT
# 13              1              1                  2  SUB-DISTRICT
# ...           ...            ...                ...           ...
# 19978          35            639               5921  SUB-DISTRICT
# 19981          35            640                  0      DISTRICT
# 19984          35            640               5922  SUB-DISTRICT
# 19987          35            640               5923  SUB-DISTRICT
# 19990          35            640               5924  SUB-DISTRICT
#
#                   Name Residence  Inhabited Villages  Uninhabited Villages  \
# 1                INDIA     Rural              597608                 43324
# ...

# %%
cleaned_census['Inhabited Villages'].sum()
# Out:
# 4768980

# %%
cleaned_census['Inhabited Villages'].mean()
# Out:
# 239.94867924528302

# %%
cleaned_census['Uninhabited Villages'].sum()
# Out:
# 345847

# %%
cleaned_census['Uninhabited Villages'].mean()
# Out:
# 17.401106918238995

# %%
cleaned_census['Inhabited Villages'].corr(cleaned_census['Uninhabited Villages'])
# Out:
# 0.9933959280861335

# %%
cleaned_census.head()
# Out:
#    State Code  District Code  Sub District Code Category             Name  \
# 0           0              0                  0    INDIA            INDIA
# 1           0              0                  0    INDIA            INDIA
# 2           0              0                  0    INDIA            INDIA
# 3           1              0                  0    STATE  JAMMU & KASHMIR
# 4           1              0                  0    STATE  JAMMU & KASHMIR
#
#   Residence  Inhabited Villages  Uninhabited Villages  Towns  Households  \
# 0     Total              597608                 43324   7933   249501663
# 1     Rural              597608                 43324      0   168612897
# 2     Urban                   0                     0   7933    80888766
# 3     Total                6337                   216    122     2119718
# 4     Rural                6337                   216      0     1553433
#
#    Population (Person)  Population (Male)  Population (Female)        Area  \
# ...

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(100,50))
ax[0,0].scatter(cleaned_census['Name'],cleaned_census['Population Density']);

# %%
cleaned_census.plot(x='Population (Male)',
                    y='Population (Female)',
                    kind='bar');

# %%
cleaned_census.head()
# Out:
#    State Code  District Code  Sub District Code Category             Name  \
# 0           0              0                  0    INDIA            INDIA
# 1           0              0                  0    INDIA            INDIA
# 2           0              0                  0    INDIA            INDIA
# 3           1              0                  0    STATE  JAMMU & KASHMIR
# 4           1              0                  0    STATE  JAMMU & KASHMIR
#
#   Residence  Inhabited Villages  Uninhabited Villages  Towns  Households  \
# 0     Total              597608                 43324   7933   249501663
# 1     Rural              597608                 43324      0   168612897
# 2     Urban                   0                     0   7933    80888766
# 3     Total                6337                   216    122     2119718
# 4     Rural                6337                   216      0     1553433
#
#    Population (Person)  Population (Male)  Population (Female)        Area  \
# ...

# %%
JAMMU=cleaned_census[cleaned_census['Name']=='JAMMU & KASHMIR']
JAMMU
# Out:
#    State Code  District Code  Sub District Code Category             Name  \
# 3           1              0                  0    STATE  JAMMU & KASHMIR
# 4           1              0                  0    STATE  JAMMU & KASHMIR
# 5           1              0                  0    STATE  JAMMU & KASHMIR
#
#   Residence  Inhabited Villages  Uninhabited Villages  Towns  Households  \
# 3     Total                6337                   216    122     2119718
# 4     Rural                6337                   216      0     1553433
# 5     Urban                   0                     0    122      566285
#
#    Population (Person)  Population (Male)  Population (Female)      Area  \
# 3             12541302            6640662              5900640  222236.0
# 4              9108060            4774477              4333583  220990.1
# 5              3433242            1866185              1567057    1245.9
#
#    Population Density
# 3               124.0
# 4                91.0
# ...

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(JAMMU['Population (Male)'],JAMMU['Population (Female)']);
ax.set(title='JAMMU & KASHMIR POPULATION(MALE VS FEMALE)',
      xlabel='Population(Male)',
      ylabel='Population(Female)');
#correlation between male and female in JAMMU & KASHMIR

# %%
fig,ax=plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax[0].bar(JAMMU['Residence'],JAMMU['Population (Male)']);
ax[1].bar(JAMMU['Residence'],JAMMU['Population (Female)']);
ax[0].set(title='MALE DISTRIBUTION',
         xlabel='Residence',
         ylabel='Population(Male)');
ax[1].set(title='FEMALE DISTRIBUTION',
        xlabel='Residence',
        ylabel='Population(Female)');

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.bar(JAMMU['Residence'],JAMMU['Population Density'])
ax.set(title='RESIDENCE VS POPULATION DENSITY',
      xlabel='Residence',
      ylabel='Population Density');

# %%
fig,ax=plt.subplots()
ax.bar(cleaned_census['Category'],cleaned_census['Population (Person)'])
ax.set(title='POPULATION IN RESIDENCES',
      xlabel='Category',
      ylabel='POPULATION');

# %%
cleaned_census.head()
# Out:
#    State Code  District Code  Sub District Code Category             Name  \
# 0           0              0                  0    INDIA            INDIA
# 1           0              0                  0    INDIA            INDIA
# 2           0              0                  0    INDIA            INDIA
# 3           1              0                  0    STATE  JAMMU & KASHMIR
# 4           1              0                  0    STATE  JAMMU & KASHMIR
#
#   Residence  Inhabited Villages  Uninhabited Villages  Towns  Households  \
# 0     Total              597608                 43324   7933   249501663
# 1     Rural              597608                 43324      0   168612897
# 2     Urban                   0                     0   7933    80888766
# 3     Total                6337                   216    122     2119718
# 4     Rural                6337                   216      0     1553433
#
#    Population (Person)  Population (Male)  Population (Female)        Area  \
# ...

# %%
INDIA=cleaned_census[cleaned_census['Name']=='INDIA']
INDIA
# Out:
#    State Code  District Code  Sub District Code Category   Name Residence  \
# 0           0              0                  0    INDIA  INDIA     Total
# 1           0              0                  0    INDIA  INDIA     Rural
# 2           0              0                  0    INDIA  INDIA     Urban
#
#    Inhabited Villages  Uninhabited Villages  Towns  Households  \
# 0              597608                 43324   7933   249501663
# 1              597608                 43324      0   168612897
# 2                   0                     0   7933    80888766
#
#    Population (Person)  Population (Male)  Population (Female)        Area  \
# 0           1210854977          623270258            587584719  3287469.00
# 1            833748852          427781058            405967794  3101473.97
# 2            377106125          195489200            181616925   102252.03
#
#    Population Density
# 0               382.0
# 1               279.0
# 2              3685.0
